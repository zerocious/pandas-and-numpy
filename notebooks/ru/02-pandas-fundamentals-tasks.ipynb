# %% [markdown]
# # 02 — Основы Pandas (задания)

# %% [markdown]
# > **Disclaimer / Дисклеймер:** Тексты заданий переведены автором репозитория с помощью ИИ (Cursor AI). Это **не** профессиональный перевод. При расхождениях ориентируйтесь на код, имена файлов и [HINTS.md](../../notes/HINTS.md).

# %%
from pathlib import Path

ROOT = Path('../..').resolve()
RAW = ROOT / 'data' / 'raw'
OUT = ROOT / 'data' / 'output'
OUT.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Задание 5.1
# DataFrame из словаря (user_id, status, revenue).
# df.info(); user_id → str, status → category.
# Фильтр: status=='active' и revenue>200.
# Колонки user_id и revenue.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 5.2
# DataFrame 5×3, индекс A–E, колонки x,y,z, числа 1–15.
# .loc: C,y=999; .iloc: последняя строка=0.
# Подтаблица x,z для B,D; z=-1 через .copy().

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 5.3
# Сгенерируйте orders: ORD-0001…, date_str DD.MM.YYYY, amount с NaN и минусами, region.
# Даты → datetime; только 2024 год.
# NaN→0; amount>=0; tier High/Low (np.where).
# Сохранить clean_orders.csv (index=False).

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 6.1
# category, product, sales.
# Сумма по category.
# Сумма и среднее по category+product (именованные agg).

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 6.2
# user_id, region, order_amount, is_completed.
# groupby region: total_revenue, avg_order, completed_orders, total_orders.
# Фильтр total_orders>=50; reset_index.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 6.3
# user_id, category, monthly_spend.
# transform: category_avg_spend.
# spend_share; is_high_value (>1.5× среднего).

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 7.1
# df_users + df_orders; left merge validate 1:m.
# fillna amount; выручка по tier.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 7.2
# q1,q2,q3 → concat; quarter Q1–Q3.
# pivot_table; growth_q3_vs_q2.

# %%
# Ваше решение здесь

# %% [markdown]
# ## Задание 7.3
# melt city + месяцы; доля месяца от города; фильтр share>0.35.

# %%
# Ваше решение здесь
