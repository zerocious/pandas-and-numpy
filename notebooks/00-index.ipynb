# %% [markdown]
# # Pandas & NumPy — course notebooks
#
# ## Solution notebooks
#
# | # | Notebook |
# |---|----------|
# | 01 | [01-numpy.ipynb](01-numpy.ipynb) |
# | 02 | [02-pandas-fundamentals.ipynb](02-pandas-fundamentals.ipynb) |
# | 03 | [03-pandas-pipelines.ipynb](03-pandas-pipelines.ipynb) |
# | 04 | [04-pandas-business.ipynb](04-pandas-business.ipynb) |
#
# ## Task notebooks (choose your language)
#
# | Language | Folder |
# |----------|--------|
# | **Русский** | [ru/](ru/README.md) — задания на русском |
# | **English** | [en/](en/README.md) — tasks in English |
#
# > **Disclaimer:** The EN/RU task texts were translated by the repository author using AI (not professional translations).
#
# ## How to study
#
# 1. Open the task notebook in `ru/` or `en/`.
# 2. Write code under `# Your solution here` / `# Ваше решение здесь`.
# 3. Compare with the solution notebook above.
# 4. Track progress in [../notes/PROGRESS.md](../notes/PROGRESS.md).
# 5. Stuck? [../notes/HINTS.md](../notes/HINTS.md)
#
# ## Verify
#
# ```bash
# pytest
# python ../scripts/run_solution_notebooks.py
# ```
