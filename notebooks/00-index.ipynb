# %% [markdown]
# # Pandas & NumPy — course notebooks
#
# ## English
#
# Portfolio of **solution notebooks** plus **task** notebooks in [`en/`](en/) (English) and [`ru/`](ru/) (Russian).
#
# | Solutions | Tasks (EN) |
# |-----------|------------|
# | [01-numpy.ipynb](01-numpy.ipynb) | [01-numpy-tasks.ipynb](en/01-numpy-tasks.ipynb) |
# | [02-pandas-fundamentals.ipynb](02-pandas-fundamentals.ipynb) | [02-pandas-fundamentals-tasks.ipynb](en/02-pandas-fundamentals-tasks.ipynb) |
# | [03-pandas-pipelines.ipynb](03-pandas-pipelines.ipynb) | [03-pandas-pipelines-tasks.ipynb](en/03-pandas-pipelines-tasks.ipynb) |
# | [04-pandas-business.ipynb](04-pandas-business.ipynb) | [04-pandas-business-tasks.ipynb](en/04-pandas-business-tasks.ipynb) |
#
# Hints: [../notes/HINTS.en.md](../notes/HINTS.en.md) · Showcase: [../docs/SHOWCASE.md](../docs/SHOWCASE.md)
#
# ---
#
# ## Русский
#
# Решения — в ноутбуках выше; **задания** — в папке [`ru/`](ru/).
#
# | Задания (RU) |
# |--------------|
# | [01-numpy-tasks.ipynb](ru/01-numpy-tasks.ipynb) |
# | [02-pandas-fundamentals-tasks.ipynb](ru/02-pandas-fundamentals-tasks.ipynb) |
# | [03-pandas-pipelines-tasks.ipynb](ru/03-pandas-pipelines-tasks.ipynb) |
# | [04-pandas-business-tasks.ipynb](ru/04-pandas-business-tasks.ipynb) |
#
# Подсказки: [../notes/HINTS.ru.md](../notes/HINTS.ru.md)
#
# > Task texts translated with AI assistance — see [README](../README.md).
#
# ## Verify
#
# ```bash
# pytest
# ```
