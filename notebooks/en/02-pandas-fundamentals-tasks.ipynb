# %% [markdown]
# # 02 — Pandas fundamentals (tasks)

# %% [markdown]
# > **Disclaimer:** Task descriptions were translated by the repository author using AI assistance (Cursor AI). This is **not** a professional translation. If anything is unclear, refer to code syntax, file names, and [HINTS.md](../../notes/HINTS.md).

# %%
from pathlib import Path

ROOT = Path('../..').resolve()
RAW = ROOT / 'data' / 'raw'
OUT = ROOT / 'data' / 'output'
OUT.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Task 5.1
# DataFrame from dict (user_id, status, revenue).
# df.info(); cast user_id to str, status to category.
# Filter active and revenue>200.
# Columns user_id, revenue only.

# %%
# Your solution here

# %% [markdown]
# ## Task 5.2
# 5×3 DataFrame, index A–E, columns x,y,z, values 1–15.
# .loc C,y=999; .iloc last row=0.
# Subset x,z for rows B,D; set z=-1 using .copy().

# %%
# Your solution here

# %% [markdown]
# ## Task 5.3
# Synthetic orders: ORD ids, DD.MM.YYYY dates, amounts with NaN/negatives, regions.
# Parse dates; keep 2024 only.
# fillna 0; drop negatives; tier with np.where.
# Save clean_orders.csv.

# %%
# Your solution here

# %% [markdown]
# ## Task 6.1
# category, product, sales.
# Sum per category.
# Sum and mean per category+product (named agg).

# %%
# Your solution here

# %% [markdown]
# ## Task 6.2
# Group by region: revenue, avg, completed count, order count.
# Filter total_orders>=50; reset_index.

# %%
# Your solution here

# %% [markdown]
# ## Task 6.3
# transform mean per category; spend_share; is_high_value flag.

# %%
# Your solution here

# %% [markdown]
# ## Task 7.1
# left merge users/orders validate 1:m; fillna; revenue by tier.

# %%
# Your solution here

# %% [markdown]
# ## Task 7.2
# concat quarters; pivot_table; Q3 minus Q2 growth.

# %%
# Your solution here

# %% [markdown]
# ## Task 7.3
# melt wide months; city revenue share; filter share>0.35.

# %%
# Your solution here
